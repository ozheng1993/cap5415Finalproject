# %% [markdown]
# # Mask R-CNN laoding
#
# A quick intro to using the pre-trained model to detect and segment objects.

# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf

# Root directory of the project
ROOT_DIR = os.path.abspath("./maskrcnn/")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
# Import COCO config
sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
import coco

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# Directory of images to run detection on
IMAGE_DIR = os.path.join(ROOT_DIR, "OTB50/Gym")
gt_dir=IMAGE_DIR+"/groundtruth_rect.txt"
img_dir=IMAGE_DIR+"/img/"

#Configurations
class InferenceConfig(coco.CocoConfig):
    # Set batch size to 1 since we'll be running inference on
    # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
#config.display()
# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)

# Load weights trained on MS-COCO
model.load_weights(COCO_MODEL_PATH, by_name=True)
# COCO Class names
# Index of the class in the list is its ID. For example, to get ID of
# the teddy bear class, use: class_names.index('teddy bear')
class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Run Object Detection

# %%
from math import sqrt
if  not (os.path.isfile('goturn.caffemodel') and os.path.isfile('goturn.prototxt')):
    errorMsg = '''
    Could not find GOTURN model in current directory.
    Please ensure goturn.caffemodel and goturn.prototxt are in the current directory
    '''

    print(errorMsg)
    sys.exit()

frame_index=1    
resize_scale=2
    
text1="index,gtx,gty,gtw,gth,gotunx,goturny,goturnw,goturnh,newx,newy,neww,newh\n"
with open("ou_benchmark.txt", "a") as myfile:
        myfile.write(text1)    

# Create tracker
tracker = cv2.TrackerGOTURN_create()   
tracker2 = cv2.TrackerGOTURN_create()   

# print(gt_dir)
# print(img_dir)
file = open(gt_dir, 'r') 

for line in file: 
    
    
    print(frame_index)
    image_name=img_dir+str(frame_index).zfill(4)+".jpg"
    print(image_name)
    #Load an color image in grayscale
    img = cv2.imread(image_name,1)
    img2 = cv2.imread(image_name,1)
    gt_img=cv2.imread(image_name,1)
    mask_img=cv2.imread(image_name,1)
    gotunrn_img=cv2.imread(image_name,1)
    gotunrn_img2=cv2.imread(image_name,1)
    print(line[1])
    print(img.shape)
    height,width,channel=img.shape
    line=line.split(",")
    x1=int(line[0])
    y1=int(line[1])
    x2=int(line[2])
    y2=int(line[3])
    print(x1)
    print(x2)
    print(y1)
    print(y2)
    gt_data=str(x1)+","+str(y1)+","+str(x2)+","+str(y2)
    if(frame_index==1):
        bbox = (x1,y1, x2, y2)
        bbox2 = (x1,y1, x2, y2)
        gotunrn_img = tracker.init(img,bbox)
        gotunrn_img2 = tracker2.init(img2,bbox2)
        frame_index+=1
        continue
    
    gotunrn_img, bbox = tracker.update(img)
    gotunrn_img2, bbox2 = tracker2.update(img2)
      # Draw bounding box
    if gotunrn_img:
        # Tracking success
        p1 = (int(bbox[0]), int(bbox[1]))
        p2 = (int(bbox[0] + bbox[2]), int(bbox[1] + bbox[3]))
        cx1 =int(bbox[0] + bbox[2]/2)
        cy1 =int(bbox[1] + bbox[3]/2)
        cw1=bbox[2]
        ch1=bbox[3]
        goturn_data=str(int(bbox[0]))+","+str(int(bbox[1]))+","+str(cw1)+","+str(ch1)
        cv2.rectangle(img, p1, p2, (255,255,0), 2, 1)
        #cv2.circle(img, (cx1,cy1), 3,(255,255,0), 1, 8,0)
#         print("==================goturn=================")
#         print(cx1)
#         print(cy1)
#         print(cw1)
#         print(ch1)
#         print("==================goturn=================")
    else :
        # Tracking failure
        print("tracking1 fail")
    # Display result
#     cv2.imshow("Tracking", img) 
    if gotunrn_img2:
        # Tracking success
        p3 = (int(bbox2[0]), int(bbox2[1]))
        p4 = (int(bbox2[0] + bbox2[2]), int(bbox2[1] + bbox2[3]))
        cx2 =int(bbox2[0] + bbox2[2]/2)
        cy2 =int(bbox2[1] + bbox2[3]/2)
        cw2=bbox2[2]
        ch2=bbox2[3]
        cv2.rectangle(img2, p3, p4, (0,0,255), 2, 1)
        goturn_data2=str(int(bbox2[0]))+","+str(int(bbox2[1]))+","+str(cw2)+","+str(ch2)
        #cv2.circle(img, (cx2,cy2), 3,(255,255,255), 1, 8,0)
#         print("==================goturn+maskrcnn=================")
#         print(cx2)
#         print(cy2)
#         print(cw2)
#         print(ch2)
#         print("==================goturn+maskrcnn=================")
    else :
        # Tracking failure
        print("tracking1 fail")
    # Display result
    cv2.imshow("new goturn", img2) 
    cv2.imshow("goturn", img) 
    resized_image = cv2.resize(mask_img, (width*resize_scale, height*resize_scale)) 
    image=resized_image
    results = model.detect([image], verbose=1)
    r = results[0]
    range_in_r=len(r["rois"])
    
    for i in range(range_in_r):
        p1=(r["rois"][i][1],r["rois"][i][0])
        p2=(r["rois"][i][3],r["rois"][i][2])
        cx3=int(r["rois"][i][1]+(r["rois"][i][3]-r["rois"][i][1])/2)
        cy3=int(r["rois"][i][0]+(r["rois"][i][2]-r["rois"][i][0])/2)
        cw3=int(r["rois"][i][3]-r["rois"][i][1])
        ch3=int(r["rois"][i][2]-r["rois"][i][0])
        
        dist = sqrt( (cx3/resize_scale - cx2)**2 + (cy3/resize_scale - cy2)**2 )
        cv2.rectangle(image, p1, p2, (255,0,0), 2, 1) 
        if(dist<=8):
            tmp_id=class_names[r["class_ids"][i]]
            tmp_score=r['scores'][i]
            tmp_final=str(tmp_id)+str(tmp_score)
            font = cv2.FONT_HERSHEY_SIMPLEX
            
            #cv2.circle(image, (cx3,cy3), 3,(255,0,0), 1, 8,0)
            print("==================maskrcnn=================")
            
            print(cx3/resize_scale)
            print(cy3/resize_scale)
            print(cw3)
            print(ch3)
            print(dist)
            widthDiff=abs(cx3/resize_scale -cx2)
            heightDiff=abs(cx3/resize_scale -cx2)
            
            print("-------differetn---")
            print(widthDiff)
            print(heightDiff)
            print(cx3/resize_scale/20)
            print(cy3/resize_scale/20)
            if(widthDiff>=1 or heightDiff>=1 or dist>0.5):
                print("updategoturn +++++++++++++++++++++++++++++++++")
                update_x=r["rois"][i][1]/resize_scale
                update_y=r["rois"][i][0]/resize_scale
                update_w=cw3/resize_scale
                update_h=ch3/resize_scale
                print(p1)
                print(p2)

                print("update")
           
                print(update_x)
                print(update_y)
                print(update_w)
                print(update_h)
                print("gt")
                print(x1)
                print(y1)
                print(x1+x2)
                print(y1+y2)
                #car id
                if(r["class_ids"][i]==3):
                    bbox2 = (update_x,update_y, update_w, update_h)
                    tracker2 = cv2.TrackerGOTURN_create()  
                    gotunrn_img2 = tracker2.init(img2,bbox2)
            print("==================maskrcnn=================")
            cv2.putText(image,tmp_final,p1, font, 1,(255,255,255),2,cv2.LINE_AA)
    resized_back_image = cv2.resize(image, (width, height)) 
    cv2.imshow('maskrcnn',resized_back_image)
    #cv2.imshow('orgin',img)
    cv2.rectangle(gt_img, (x1,y1), (x1+x2,y1+y2), (0,255,0), 3, 1) 
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(gt_img,"gt",(x1,y1+5), font, 0.5,(255,255,255),1,cv2.LINE_AA)
    cv2.imshow('gt_img',gt_img)
    text=str(frame_index)+","+gt_data+","+goturn_data+","+goturn_data2+"\n"
    with open("ou_benchmark.txt", "a") as myfile:
        myfile.write(text)
    cv2.waitKey(1)
    
    frame_index+=1
        # Exit if ESC pressed
    k = cv2.waitKey(1) & 0xff
    if k == 27:
        break
    if(frame_index>500):
        break
cv2.destroyAllWindows()
# Out:
# 1
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0001.jpg
# 6
# (234, 426, 3)
# 167
# 24
# 69
# 127
# 2
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0002.jpg
# 6
# (234, 426, 3)
# 167
# 29
# 65
# 131
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    2.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 187.0
# 133.5
# 136
# 279
# 6.18465843842649
# -------differetn---
# 6.0
# 6.0
# 9.35
# 6.675
# updategoturn +++++++++++++++++++++++++++++++++
# (306, 128)
# (442, 407)
# update
# 153.0
# 64.0
# 68.0
# 139.5
# gt
# 167
# 65
# 196
# 196
# ==================maskrcnn=================
# 3
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0003.jpg
# 6
# (234, 426, 3)
# 166
# 34
# 67
# 121
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 4
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0004.jpg
# 6
# (234, 426, 3)
# 161
# 42
# 65
# 123
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 184.5
# 134.5
# 136
# 268
# 5.1478150704935
# -------differetn---
# 2.5
# 2.5
# 9.225
# 6.725
# updategoturn +++++++++++++++++++++++++++++++++
# (301, 135)
# (437, 403)
# update
# 150.5
# 67.5
# 68.0
# 134.0
# gt
# 161
# 65
# 203
# 188
# ==================maskrcnn=================
# 5
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0005.jpg
# 6
# (234, 426, 3)
# 164
# 36
# 64
# 136
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    5.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 187.0
# 134.5
# 165
# 270
# 4.272001872658765
# -------differetn---
# 4.0
# 4.0
# 9.35
# 6.725
# updategoturn +++++++++++++++++++++++++++++++++
# (292, 134)
# (457, 404)
# update
# 146.0
# 67.0
# 82.5
# 135.0
# gt
# 164
# 64
# 200
# 200
# ==================maskrcnn=================
# 6
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0006.jpg
# 6
# (234, 426, 3)
# 162
# 52
# 60
# 132
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 185.5
# 134.0
# 176
# 270
# 5.408326913195984
# -------differetn---
# 4.5
# 4.5
# 9.275
# 6.7
# updategoturn +++++++++++++++++++++++++++++++++
# (283, 133)
# (459, 403)
# update
# 141.5
# 66.5
# 88.0
# 135.0
# gt
# 162
# 60
# 214
# 192
# ==================maskrcnn=================
# 7
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0007.jpg
# 6
# (234, 426, 3)
# 169
# 39
# 61
# 136
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 184.5
# 133.5
# 187
# 272
# 2.9154759474226504
# -------differetn---
# 1.5
# 1.5
# 9.225
# 6.675
# updategoturn +++++++++++++++++++++++++++++++++
# (276, 131)
# (463, 403)
# update
# 138.0
# 65.5
# 93.5
# 136.0
# gt
# 169
# 61
# 208
# 197
# ==================maskrcnn=================
# 8
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0008.jpg
# 6
# (234, 426, 3)
# 166
# 41
# 66
# 127
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 186.0
# 134.0
# 187
# 267
# 2.23606797749979
# -------differetn---
# 1.0
# 1.0
# 9.3
# 6.7
# updategoturn +++++++++++++++++++++++++++++++++
# (279, 135)
# (466, 402)
# update
# 139.5
# 67.5
# 93.5
# 133.5
# gt
# 166
# 66
# 207
# 193
# ==================maskrcnn=================
# 9
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0009.jpg
# 6
# (234, 426, 3)
# 169
# 39
# 60
# 132
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 185.0
# 134.5
# 186
# 264
# 3.640054944640259
# -------differetn---
# 1.0
# 1.0
# 9.25
# 6.725
# updategoturn +++++++++++++++++++++++++++++++++
# (277, 137)
# (463, 401)
# update
# 138.5
# 68.5
# 93.0
# 132.0
# gt
# 169
# 60
# 208
# 192
# ==================maskrcnn=================
# 10
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0010.jpg
# 6
# (234, 426, 3)
# 168
# 38
# 66
# 127
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  147.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 182.5
# 134.0
# 167
# 269
# 5.852349955359813
# -------differetn---
# 5.5
# 5.5
# 9.125
# 6.7
# updategoturn +++++++++++++++++++++++++++++++++
# (282, 134)
# (449, 403)
# update
# 141.0
# 67.0
# 83.5
# 134.5
# gt
# 168
# 66
# 206
# 193
# ==================maskrcnn=================
# 11
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0011.jpg
# 6
# (234, 426, 3)
# 168
# 37
# 66
# 132
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 188.5
# 134.0
# 192
# 267
# 2.5
# -------differetn---
# 1.5
# 1.5
# 9.425
# 6.7
# updategoturn +++++++++++++++++++++++++++++++++
# (281, 135)
# (473, 402)
# update
# 140.5
# 67.5
# 96.0
# 133.5
# gt
# 168
# 66
# 205
# 198
# ==================maskrcnn=================
# 12
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0012.jpg
# 6
# (234, 426, 3)
# 164
# 40
# 68
# 125
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 13
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0013.jpg
# 6
# (234, 426, 3)
# 160
# 51
# 69
# 128
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 14
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0014.jpg
# 6
# (234, 426, 3)
# 167
# 43
# 69
# 128
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  147.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 185.0
# 133.5
# 71
# 285
# 4.272001872658765
# -------differetn---
# 4.0
# 4.0
# 9.25
# 6.675
# updategoturn +++++++++++++++++++++++++++++++++
# (335, 125)
# (406, 410)
# update
# 167.5
# 62.5
# 35.5
# 142.5
# gt
# 167
# 69
# 210
# 197
# ==================maskrcnn=================
# 15
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0015.jpg
# 6
# (234, 426, 3)
# 163
# 49
# 69
# 130
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 188.0
# 138.5
# 154
# 263
# 3.640054944640259
# -------differetn---
# 1.0
# 1.0
# 9.4
# 6.925
# updategoturn +++++++++++++++++++++++++++++++++
# (299, 146)
# (453, 409)
# update
# 149.5
# 73.0
# 77.0
# 131.5
# gt
# 163
# 69
# 212
# 199
# ==================maskrcnn=================
# 16
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0016.jpg
# 6
# (234, 426, 3)
# 161
# 52
# 72
# 133
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    2.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 188.0
# 138.5
# 75
# 278
# 3.0413812651491097
# -------differetn---
# 3.0
# 3.0
# 9.4
# 6.925
# updategoturn +++++++++++++++++++++++++++++++++
# (339, 138)
# (414, 416)
# update
# 169.5
# 69.0
# 37.5
# 139.0
# gt
# 161
# 72
# 213
# 205
# ==================maskrcnn=================
# 17
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0017.jpg
# 6
# (234, 426, 3)
# 164
# 50
# 70
# 131
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 189.0
# 140.0
# 76
# 265
# 2.8284271247461903
# -------differetn---
# 2.0
# 2.0
# 9.45
# 7.0
# updategoturn +++++++++++++++++++++++++++++++++
# (340, 148)
# (416, 413)
# update
# 170.0
# 74.0
# 38.0
# 132.5
# gt
# 164
# 70
# 214
# 201
# ==================maskrcnn=================
# 18
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0018.jpg
# 6
# (234, 426, 3)
# 161
# 57
# 75
# 130
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 187.5
# 140.5
# 71
# 271
# 5.1478150704935
# -------differetn---
# 4.5
# 4.5
# 9.375
# 7.025
# updategoturn +++++++++++++++++++++++++++++++++
# (340, 146)
# (411, 417)
# update
# 170.0
# 73.0
# 35.5
# 135.5
# gt
# 161
# 75
# 218
# 205
# ==================maskrcnn=================
# 19
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0019.jpg
# 6
# (234, 426, 3)
# 163
# 54
# 73
# 129
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 188.0
# 141.0
# 65
# 268
# 3.0
# -------differetn---
# 3.0
# 3.0
# 9.4
# 7.05
# updategoturn +++++++++++++++++++++++++++++++++
# (344, 148)
# (409, 416)
# update
# 172.0
# 74.0
# 32.5
# 134.0
# gt
# 163
# 73
# 217
# 202
# ==================maskrcnn=================
# 20
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0020.jpg
# 5
# (234, 426, 3)
# 159
# 53
# 75
# 132
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    1.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 189.5
# 142.5
# 71
# 266
# 1.5811388300841898
# -------differetn---
# 1.5
# 1.5
# 9.475
# 7.125
# updategoturn +++++++++++++++++++++++++++++++++
# (344, 152)
# (415, 418)
# update
# 172.0
# 76.0
# 35.5
# 133.0
# gt
# 159
# 75
# 212
# 207
# ==================maskrcnn=================
# 21
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0021.jpg
# 6
# (234, 426, 3)
# 164
# 47
# 83
# 126
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 189.5
# 145.5
# 77
# 260
# 2.9154759474226504
# -------differetn---
# 2.5
# 2.5
# 9.475
# 7.275
# updategoturn +++++++++++++++++++++++++++++++++
# (341, 161)
# (418, 421)
# update
# 170.5
# 80.5
# 38.5
# 130.0
# gt
# 164
# 83
# 211
# 209
# ==================maskrcnn=================
# 22
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0022.jpg
# 6
# (234, 426, 3)
# 166
# 49
# 81
# 124
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 23
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0023.jpg
# 6
# (234, 426, 3)
# 163
# 49
# 80
# 133
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 24
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0024.jpg
# 6
# (234, 426, 3)
# 163
# 50
# 80
# 131
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 25
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0025.jpg
# 5
# (234, 426, 3)
# 159
# 54
# 87
# 125
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 26
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0026.jpg
# 6
# (234, 426, 3)
# 160
# 55
# 84
# 121
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 27
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0027.jpg
# 5
# (234, 426, 3)
# 159
# 53
# 80
# 132
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 28
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0028.jpg
# 5
# (234, 426, 3)
# 159
# 55
# 75
# 133
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  147.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 29
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0029.jpg
# 5
# (234, 426, 3)
# 159
# 59
# 75
# 127
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 30
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0030.jpg
# 6
# (234, 426, 3)
# 160
# 57
# 77
# 122
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 31
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0031.jpg
# 6
# (234, 426, 3)
# 160
# 56
# 72
# 129
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  147.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 32
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0032.jpg
# 5
# (234, 426, 3)
# 159
# 55
# 65
# 138
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    1.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 33
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0033.jpg
# 6
# (234, 426, 3)
# 161
# 59
# 62
# 141
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    1.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 34
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0034.jpg
# 6
# (234, 426, 3)
# 164
# 57
# 72
# 133
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    1.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 35
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0035.jpg
# 6
# (234, 426, 3)
# 160
# 53
# 63
# 144
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    2.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 36
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0036.jpg
# 6
# (234, 426, 3)
# 163
# 61
# 67
# 139
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    1.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 37
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0037.jpg
# 6
# (234, 426, 3)
# 163
# 59
# 70
# 130
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    1.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 38
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0038.jpg
# 6
# (234, 426, 3)
# 167
# 53
# 71
# 128
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    2.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 39
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0039.jpg
# 7
# (234, 426, 3)
# 173
# 51
# 72
# 128
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 40
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0040.jpg
# 7
# (234, 426, 3)
# 171
# 48
# 70
# 131
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  147.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 41
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0041.jpg
# 7
# (234, 426, 3)
# 173
# 51
# 70
# 129
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 42
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0042.jpg
# 7
# (234, 426, 3)
# 177
# 51
# 65
# 132
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  147.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 43
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0043.jpg
# 8
# (234, 426, 3)
# 180
# 49
# 62
# 129
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 44
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0044.jpg
# 7
# (234, 426, 3)
# 176
# 56
# 63
# 129
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    5.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 45
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0045.jpg
# 7
# (234, 426, 3)
# 179
# 50
# 66
# 124
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    5.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 46
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0046.jpg
# 8
# (234, 426, 3)
# 181
# 45
# 66
# 131
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 47
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0047.jpg
# 7
# (234, 426, 3)
# 176
# 46
# 68
# 125
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    5.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 48
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0048.jpg
# 7
# (234, 426, 3)
# 178
# 42
# 70
# 126
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 49
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0049.jpg
# 8
# (234, 426, 3)
# 180
# 46
# 70
# 120
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    5.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 50
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0050.jpg
# 7
# (234, 426, 3)
# 178
# 49
# 74
# 118
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 51
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0051.jpg
# 8
# (234, 426, 3)
# 181
# 44
# 81
# 107
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    6.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 52
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0052.jpg
# 8
# (234, 426, 3)
# 186
# 40
# 83
# 114
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 53
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0053.jpg
# 8
# (234, 426, 3)
# 187
# 37
# 85
# 109
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 54
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0054.jpg
# 8
# (234, 426, 3)
# 186
# 45
# 82
# 109
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    5.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 55
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0055.jpg
# 7
# (234, 426, 3)
# 179
# 43
# 79
# 110
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    1.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 56
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0056.jpg
# 7
# (234, 426, 3)
# 174
# 49
# 82
# 114
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 57
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0057.jpg
# 7
# (234, 426, 3)
# 179
# 40
# 78
# 112
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 58
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0058.jpg
# 7
# (234, 426, 3)
# 177
# 46
# 80
# 106
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    1.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 59
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0059.jpg
# 6
# (234, 426, 3)
# 167
# 57
# 82
# 107
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    1.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 60
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0060.jpg
# 6
# (234, 426, 3)
# 169
# 56
# 76
# 119
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    1.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 61
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0061.jpg
# 7
# (234, 426, 3)
# 173
# 52
# 80
# 110
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    2.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 62
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0062.jpg
# 7
# (234, 426, 3)
# 170
# 58
# 82
# 115
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    2.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 63
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0063.jpg
# 6
# (234, 426, 3)
# 169
# 66
# 82
# 118
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 64
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0064.jpg
# 7
# (234, 426, 3)
# 170
# 61
# 81
# 112
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 65
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0065.jpg
# 7
# (234, 426, 3)
# 171
# 54
# 80
# 118
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    2.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 66
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0066.jpg
# 6
# (234, 426, 3)
# 167
# 59
# 79
# 115
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 67
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0067.jpg
# 7
# (234, 426, 3)
# 171
# 50
# 73
# 127
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    6.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 68
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0068.jpg
# 6
# (234, 426, 3)
# 169
# 61
# 80
# 114
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 69
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0069.jpg
# 7
# (234, 426, 3)
# 172
# 55
# 80
# 121
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 70
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0070.jpg
# 7
# (234, 426, 3)
# 174
# 52
# 76
# 116
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    6.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 71
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0071.jpg
# 7
# (234, 426, 3)
# 171
# 57
# 79
# 100
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 72
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0072.jpg
# 7
# (234, 426, 3)
# 170
# 55
# 77
# 116
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    5.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 73
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0073.jpg
# 6
# (234, 426, 3)
# 167
# 55
# 79
# 120
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    5.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 74
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0074.jpg
# 7
# (234, 426, 3)
# 170
# 44
# 75
# 125
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    3.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  147.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 75
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0075.jpg
# 6
# (234, 426, 3)
# 166
# 43
# 80
# 124
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    8.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  147.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 189.5
# 148.0
# 87
# 244
# 3.905124837953327
# -------differetn---
# 2.5
# 2.5
# 9.475
# 7.4
# updategoturn +++++++++++++++++++++++++++++++++
# (336, 174)
# (423, 418)
# update
# 168.0
# 87.0
# 43.5
# 122.0
# gt
# 166
# 80
# 209
# 204
# ==================maskrcnn=================
# 76
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0076.jpg
# 6
# (234, 426, 3)
# 169
# 42
# 78
# 126
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    6.00000  max:  254.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 189.5
# 149.0
# 80
# 243
# 7.5
# -------differetn---
# 4.5
# 4.5
# 9.475
# 7.45
# updategoturn +++++++++++++++++++++++++++++++++
# (339, 177)
# (419, 420)
# update
# 169.5
# 88.5
# 40.0
# 121.5
# gt
# 169
# 78
# 211
# 204
# ==================maskrcnn=================
# 77
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0077.jpg
# 7
# (234, 426, 3)
# 177
# 30
# 81
# 117
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    8.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 192.5
# 149.5
# 68
# 235
# 7.905694150420948
# -------differetn---
# 2.5
# 2.5
# 9.625
# 7.475
# updategoturn +++++++++++++++++++++++++++++++++
# (351, 182)
# (419, 417)
# update
# 175.5
# 91.0
# 34.0
# 117.5
# gt
# 177
# 81
# 207
# 198
# ==================maskrcnn=================
# 78
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0078.jpg
# 7
# (234, 426, 3)
# 174
# 44
# 82
# 120
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    7.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 79
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0079.jpg
# 6
# (234, 426, 3)
# 167
# 51
# 80
# 117
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    6.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 202.5
# 148.5
# 122
# 237
# 4.743416490252569
# -------differetn---
# 4.5
# 4.5
# 10.125
# 7.425
# updategoturn +++++++++++++++++++++++++++++++++
# (344, 179)
# (466, 416)
# update
# 172.0
# 89.5
# 61.0
# 118.5
# gt
# 167
# 80
# 218
# 197
# ==================maskrcnn=================
# 80
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0080.jpg
# 6
# (234, 426, 3)
# 169
# 60
# 76
# 122
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    6.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 206.0
# 146.0
# 142
# 248
# 2.23606797749979
# -------differetn---
# 2.0
# 2.0
# 10.3
# 7.3
# updategoturn +++++++++++++++++++++++++++++++++
# (341, 168)
# (483, 416)
# update
# 170.5
# 84.0
# 71.0
# 124.0
# gt
# 169
# 76
# 229
# 198
# ==================maskrcnn=================
# 81
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0081.jpg
# 6
# (234, 426, 3)
# 165
# 68
# 79
# 110
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    2.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 211.5
# 146.0
# 162
# 242
# 6.800735254367722
# -------differetn---
# 5.5
# 5.5
# 10.575
# 7.3
# updategoturn +++++++++++++++++++++++++++++++++
# (342, 171)
# (504, 413)
# update
# 171.0
# 85.5
# 81.0
# 121.0
# gt
# 165
# 79
# 233
# 189
# ==================maskrcnn=================
# 82
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0082.jpg
# 7
# (234, 426, 3)
# 174
# 55
# 79
# 109
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    4.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 83
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0083.jpg
# 7
# (234, 426, 3)
# 172
# 64
# 78
# 110
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    5.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  148.10000  float64
# ...
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 214
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0214.jpg
# 8
# (234, 426, 3)
# 189
# 40
# 82
# 128
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 215
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0215.jpg
# 8
# (234, 426, 3)
# 189
# 36
# 74
# 133
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 216
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0216.jpg
# 9
# (234, 426, 3)
# 190
# 33
# 76
# 133
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 217
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0217.jpg
# 8
# (234, 426, 3)
# 183
# 40
# 70
# 137
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 218
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0218.jpg
# 8
# (234, 426, 3)
# 184
# 37
# 72
# 135
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 206.5
# 143.5
# 65
# 260
# 7.3824115301167
# -------differetn---
# 3.5
# 3.5
# 10.325
# 7.175
# updategoturn +++++++++++++++++++++++++++++++++
# (381, 157)
# (446, 417)
# update
# 190.5
# 78.5
# 32.5
# 130.0
# gt
# 184
# 72
# 221
# 207
# ==================maskrcnn=================
# 219
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0219.jpg
# 8
# (234, 426, 3)
# 188
# 35
# 77
# 127
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 205.5
# 143.0
# 67
# 263
# 4.031128874149275
# -------differetn---
# 3.5
# 3.5
# 10.275
# 7.15
# updategoturn +++++++++++++++++++++++++++++++++
# (378, 155)
# (445, 418)
# update
# 189.0
# 77.5
# 33.5
# 131.5
# gt
# 188
# 77
# 223
# 204
# ==================maskrcnn=================
# 220
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0220.jpg
# 8
# (234, 426, 3)
# 186
# 36
# 74
# 139
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 205.5
# 142.5
# 64
# 249
# 3.8078865529319543
# -------differetn---
# 3.5
# 3.5
# 10.275
# 7.125
# updategoturn +++++++++++++++++++++++++++++++++
# (379, 161)
# (443, 410)
# update
# 189.5
# 80.5
# 32.0
# 124.5
# gt
# 186
# 74
# 222
# 213
# ==================maskrcnn=================
# 221
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0221.jpg
# 8
# (234, 426, 3)
# 183
# 36
# 71
# 142
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 203.5
# 144.0
# 76
# 256
# 4.924428900898052
# -------differetn---
# 4.5
# 4.5
# 10.175
# 7.2
# updategoturn +++++++++++++++++++++++++++++++++
# (369, 160)
# (445, 416)
# update
# 184.5
# 80.0
# 38.0
# 128.0
# gt
# 183
# 71
# 219
# 213
# ==================maskrcnn=================
# 222
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0222.jpg
# 8
# (234, 426, 3)
# 186
# 35
# 74
# 136
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 204.0
# 144.5
# 73
# 256
# 3.3541019662496847
# -------differetn---
# 3.0
# 3.0
# 10.2
# 7.225
# updategoturn +++++++++++++++++++++++++++++++++
# (372, 161)
# (445, 417)
# update
# 186.0
# 80.5
# 36.5
# 128.0
# gt
# 186
# 74
# 221
# 210
# ==================maskrcnn=================
# 223
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0223.jpg
# 8
# (234, 426, 3)
# 184
# 37
# 75
# 129
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 203.0
# 147.0
# 68
# 250
# 5.656854249492381
# -------differetn---
# 4.0
# 4.0
# 10.15
# 7.35
# updategoturn +++++++++++++++++++++++++++++++++
# (372, 169)
# (440, 419)
# update
# 186.0
# 84.5
# 34.0
# 125.0
# gt
# 184
# 75
# 221
# 204
# ==================maskrcnn=================
# 224
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0224.jpg
# 8
# (234, 426, 3)
# 182
# 36
# 77
# 133
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 203.0
# 148.0
# 67
# 246
# 7.615773105863909
# -------differetn---
# 3.0
# 3.0
# 10.15
# 7.4
# updategoturn +++++++++++++++++++++++++++++++++
# (373, 173)
# (440, 419)
# update
# 186.5
# 86.5
# 33.5
# 123.0
# gt
# 182
# 77
# 218
# 210
# ==================maskrcnn=================
# 225
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0225.jpg
# 8
# (234, 426, 3)
# 180
# 42
# 76
# 130
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 204.0
# 145.5
# 64
# 241
# 5.5901699437494745
# -------differetn---
# 1.0
# 1.0
# 10.2
# 7.275
# updategoturn +++++++++++++++++++++++++++++++++
# (376, 171)
# (440, 412)
# update
# 188.0
# 85.5
# 32.0
# 120.5
# gt
# 180
# 76
# 222
# 206
# ==================maskrcnn=================
# 226
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0226.jpg
# 7
# (234, 426, 3)
# 178
# 39
# 82
# 123
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 202.0
# 145.0
# 67
# 253
# 4.242640687119285
# -------differetn---
# 3.0
# 3.0
# 10.1
# 7.25
# updategoturn +++++++++++++++++++++++++++++++++
# (371, 164)
# (438, 417)
# update
# 185.5
# 82.0
# 33.5
# 126.5
# gt
# 178
# 82
# 217
# 205
# ==================maskrcnn=================
# 227
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0227.jpg
# 8
# (234, 426, 3)
# 180
# 41
# 77
# 133
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 205.5
# 130.5
# 39
# 38
# 7.648529270389178
# -------differetn---
# 1.5
# 1.5
# 10.275
# 6.525
# updategoturn +++++++++++++++++++++++++++++++++
# (392, 242)
# (431, 280)
# update
# 196.0
# 121.0
# 19.5
# 19.0
# gt
# 180
# 77
# 221
# 210
# ==================maskrcnn=================
# 228
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0228.jpg
# 7
# (234, 426, 3)
# 175
# 41
# 79
# 129
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 229
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0229.jpg
# 8
# (234, 426, 3)
# 182
# 39
# 83
# 126
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ==================maskrcnn=================
# 199.5
# 148.5
# 70
# 246
# 7.106335201775948
# -------differetn---
# 4.5
# 4.5
# 9.975
# 7.425
# updategoturn +++++++++++++++++++++++++++++++++
# (364, 174)
# (434, 420)
# update
# 182.0
# 87.0
# 35.0
# 123.0
# gt
# 182
# 83
# 221
# 209
# ==================maskrcnn=================
# 230
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0230.jpg
# 8
# (234, 426, 3)
# 180
# 41
# 80
# 127
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 231
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0231.jpg
# 8
# (234, 426, 3)
# 181
# 37
# 83
# 122
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 232
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0232.jpg
# 8
# (234, 426, 3)
# 180
# 37
# 83
# 123
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 233
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0233.jpg
# 7
# (234, 426, 3)
# 175
# 45
# 82
# 116
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 234
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0234.jpg
# 8
# (234, 426, 3)
# 181
# 39
# 80
# 118
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 235
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0235.jpg
# 7
# (234, 426, 3)
# 178
# 45
# 84
# 116
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 236
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0236.jpg
# 7
# (234, 426, 3)
# 178
# 45
# 87
# 113
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 237
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0237.jpg
# 7
# (234, 426, 3)
# 178
# 46
# 82
# 126
# Processing 1 images
# image                    shape: (468, 852, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# 238
# /home/ou-lab/Desktop/cap5415Finalproject/maskrcnn/OTB50/Gym/img/0238.jpg
# 8
# (234, 426, 3)
# 180
# 41
# 83
# 120
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c5401d03c96b> in <module>
#      59
#      60     gotunrn_img, bbox = tracker.update(img)
# ---> 61     gotunrn_img2, bbox2 = tracker2.update(img2)
#      62       # Draw bounding box
#      63     if gotunrn_img:
#
# KeyboardInterrupt:

# %% [markdown]
# print(gt_dir)
